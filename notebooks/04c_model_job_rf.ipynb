# %%
DF_PATH       = "../data/processed/2_cleaned_data.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageHaveWorkedWith',
                  'DatabaseHaveWorkedWith',
                  #'PlatformHaveWorkedWith',
                  'WebframeHaveWorkedWith',
                  'MiscTechHaveWorkedWith',
                  'ToolsTechHaveWorkedWith',
                  'NEWCollabToolsHaveWorkedWith',
                  ]

MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
# Load packages
import pandas as pd 
import numpy as np
import logging
import pickle
import random
import plotly 
import os
from pathlib import Path

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline, FeatureUnion
from sklearn.feature_selection import VarianceThreshold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.decomposition import PCA, KernelPCA

from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from matplotlib import pyplot as plt

# %% [markdown]
# _________

# %% [markdown]
# ### Functions

# %%
def calculate_quality(ground_truth, predictions, metric_function, sort_values=False):
    quality_scores = {}
    for col in predictions.columns:
        role_pred  = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        quality_scores[col] = round(metric_function(role_truth, role_pred) * 100, 2)
        
    quality_scores = pd.Series(quality_scores.values(), index=quality_scores.keys())
    if sort_values:
        quality_scores = quality_scores.sort_values()
    
    return quality_scores

# %% [markdown]
# -------------

# %% [markdown]
# ## Prep data

# %%
# Read Data
df = pd.read_pickle(DF_PATH)

# %% [markdown]
# ### Balance classes

# %%
# Check the total samples of roles
roles_df = df["DevType"].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1708
# Data or business analyst                          1658
# Data scientist or machine learning specialist     2460
# Database administrator                            1210
# DevOps specialist                                 3056
# Developer, QA or test                             1135
# Developer, back-end                              17084
# Developer, desktop or enterprise applications     4845
# Developer, embedded applications or devices       2138
# Developer, front-end                              8932
# Developer, full-stack                            20655
# Developer, game or graphics                        899
# Developer, mobile                                 4751
# Engineer, data                                    1941
# Scientist                                         1046
# System administrator                              2069
# dtype: int64

# %%
# Resample roles
samples_per_class = 1200
resampled_roles = []

for role_col in roles_df.columns:
    sub_df = roles_df.loc[roles_df[role_col] == 1].copy()

    if len(sub_df) < samples_per_class:
        # Upsample
        sub_df = sub_df.sample(samples_per_class, replace=True, random_state=0)
    else:
        # Downsample
        sub_df = sub_df.sample(samples_per_class, random_state=0)

    resampled_roles.append(sub_df)

# %%
# Construct dfs
roles_df = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()

# %%
roles_df.sum(axis=0)
# Out:
# Academic researcher                              2280
# Data or business analyst                         1965
# Data scientist or machine learning specialist    2576
# Database administrator                           1765
# DevOps specialist                                2170
# Developer, QA or test                            1514
# Developer, back-end                              5710
# Developer, desktop or enterprise applications    2690
# Developer, embedded applications or devices      1773
# Developer, front-end                             2614
# Developer, full-stack                            5602
# Developer, game or graphics                      1441
# Developer, mobile                                2155
# Engineer, data                                   2046
# Scientist                                        1910
# System administrator                             2110
# dtype: int64

# %% [markdown]
# ## Split to train and test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),
                                                    df['DevType'],
                                                    random_state=0)
# Out:
# C:\Users\Abdelrahman Ragab\AppData\Local\Temp\ipykernel_27520\2536690730.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),

# %% [markdown]
# _________

# %% [markdown]
# # Train models

# %% [markdown]
# ### Initialize MLflow

# %%
# Initialize client and experiment
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()
mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# %% [markdown]
# ### 1. Vanilla Forest

# %%
rf_clf = make_pipeline(RobustScaler(),
                       PCA(n_components=0.95),
                       RandomForestClassifier(n_jobs=8,
                                              verbose=1,
                                              random_state=0))

rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    4.5s finished
# Pipeline(steps=[('robustscaler', RobustScaler()),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=8, random_state=0, verbose=1))])

# %%
# Evaluate on train set
predictions =  pd.DataFrame(rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.4s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
mean_test_scores = test_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.2s finished

# %%
print(test_scores.mean())
test_scores.sort_values("precision_score")
# Out:
# accuracy_score     92.647500
# precision_score    93.886250
# recall_score       50.186875
# f1_score           64.286875
# dtype: float64
#                                                accuracy_score  \
# Developer, full-stack                                   83.42
# Developer, back-end                                     79.35
# Data scientist or machine learning specialist           93.81
# Developer, front-end                                    90.00
# Academic researcher                                     94.94
# Developer, desktop or enterprise applications           90.94
# Scientist                                               97.15
# Data or business analyst                                94.52
# Developer, mobile                                       93.85
# DevOps specialist                                       92.83
# Developer, embedded applications or devices             94.67
# Developer, game or graphics                             98.00
# Database administrator                                  94.92
# Engineer, data                                          93.92
# System administrator                                    93.50
# Developer, QA or test                                   96.54
#
#                                                precision_score  recall_score  \
# Developer, full-stack                                    76.97         61.44
# Developer, back-end                                      83.76         38.44
# Data scientist or machine learning specialist            87.90         62.81
# Developer, front-end                                     90.73         34.01
# Academic researcher                                      93.59         60.43
# Developer, desktop or enterprise applications            94.07         34.53
# Scientist                                                95.66         75.76
# Data or business analyst                                 95.93         48.26
# Developer, mobile                                        96.14         46.63
# DevOps specialist                                        96.57         36.89
# Developer, embedded applications or devices              97.06         39.66
# Developer, game or graphics                              97.54         75.75
# Database administrator                                   97.60         45.93
# Engineer, data                                           99.53         42.03
# System administrator                                     99.56         42.19
# Developer, QA or test                                    99.57         58.23
#
#                                                f1_score
# Developer, full-stack                             68.34
# Developer, back-end                               52.70
# Data scientist or machine learning specialist     73.27
# Developer, front-end                              49.47
# Academic researcher                               73.44
# Developer, desktop or enterprise applications     50.51
# Scientist                                         84.55
# Data or business analyst                          64.22
# Developer, mobile                                 62.80
# DevOps specialist                                 53.39
# Developer, embedded applications or devices       56.31
# Developer, game or graphics                       85.28
# Database administrator                            62.46
# Engineer, data                                    59.10
# System administrator                              59.27
# Developer, QA or test                             73.48

# %% [markdown]
# ### Log

# %%
## Log
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices": X_test.index.tolist(),
                "features_names": X_train.columns.droplevel(0).tolist(),
                "targets_names": Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA - Basic",
         "model_details": str(rf_clf),
         "model_object": rf_clf}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Performance details
classes_metrics = {"train_scores": train_scores,
                   "test_scores": test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)

# %% [markdown]
# ______________

# %% [markdown]
# ### 2. Hyper parameter tuning

# %%
hpt_rf_clf = make_pipeline(RobustScaler(),
                           PCA(),
                           RandomForestClassifier(n_jobs=8,
                                                  verbose=1,
                                                  random_state=0))

# %%
# list(hpt_rf_clf.get_params().keys())
tuned_parameters = [{
    'pca__n_components': [0.7, 0.85, 0.95],
    'randomforestclassifier__n_estimators': [250, 500],
    'randomforestclassifier__max_depth':    [3, 10, None],
}]

# %%
hpt_rf_clf = GridSearchCV(hpt_rf_clf, tuned_parameters)
hpt_rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 485 out of 500 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    3.0s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    3.1s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    4.8s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    4.9s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    5.0s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 485 out of 500 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 485 out of 500 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 485 out of 500 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 485 out of 500 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 485 out of 500 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.8s finished
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 18 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\decomposition\_pca.py", line 433, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\decomposition\_pca.py", line 483, in _fit
#     return self._fit_full(X, n_components)
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\decomposition\_pca.py", line 518, in _fit_full
#     U, S, Vt = linalg.svd(X, full_matrices=False)
#   File "C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\scipy\linalg\_decomp_svd.py", line 131, in svd
#     raise LinAlgError("SVD did not converge")
# numpy.linalg.LinAlgError: SVD did not converge
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# GridSearchCV(estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(n_jobs=8,
#                                                                random_state=0,
#                                                                verbose=1))]),
#              param_grid=[{'pca__n_components': [0.7, 0.85, 0.95],
#                           'randomforestclassifier__max_depth': [3, 10, None],
#                           'randomforestclassifier__n_estimators': [250, 500]}])

# %%
hpt_rf_clf.best_params_
# Out:
# {'pca__n_components': 0.7,
#  'randomforestclassifier__max_depth': 3,
#  'randomforestclassifier__n_estimators': 250}

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.0s finished
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(test_scores.mean())
test_scores
# Out:
# accuracy_score     86.869375
# precision_score     0.000000
# recall_score        0.000000
# f1_score            0.000000
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     88.42
# Data or business analyst                                89.81
# Data scientist or machine learning specialist           86.50
# Database administrator                                  90.79
# DevOps specialist                                       88.88
# Developer, QA or test                                   91.77
# Developer, back-end                                     70.08
# Developer, desktop or enterprise applications           86.60
# Developer, embedded applications or devices             91.33
# Developer, front-end                                    85.60
# Developer, full-stack                                   70.88
# Developer, game or graphics                             92.35
# Developer, mobile                                       88.88
# Engineer, data                                          89.54
# Scientist                                               89.69
# System administrator                                    88.79
#
#                                                precision_score  recall_score  \
# Academic researcher                                        0.0           0.0
# Data or business analyst                                   0.0           0.0
# Data scientist or machine learning specialist              0.0           0.0
# Database administrator                                     0.0           0.0
# DevOps specialist                                          0.0           0.0
# Developer, QA or test                                      0.0           0.0
# Developer, back-end                                        0.0           0.0
# Developer, desktop or enterprise applications              0.0           0.0
# Developer, embedded applications or devices                0.0           0.0
# Developer, front-end                                       0.0           0.0
# Developer, full-stack                                      0.0           0.0
# Developer, game or graphics                                0.0           0.0
# Developer, mobile                                          0.0           0.0
# Engineer, data                                             0.0           0.0
# Scientist                                                  0.0           0.0
# System administrator                                       0.0           0.0
#
#                                                f1_score
# Academic researcher                                 0.0
# Data or business analyst                            0.0
# Data scientist or machine learning specialist       0.0
# Database administrator                              0.0
# DevOps specialist                                   0.0
# Developer, QA or test                               0.0
# Developer, back-end                                 0.0
# Developer, desktop or enterprise applications       0.0
# Developer, embedded applications or devices         0.0
# Developer, front-end                                0.0
# Developer, full-stack                               0.0
# Developer, game or graphics                         0.0
# Developer, mobile                                   0.0
# Engineer, data                                      0.0
# Scientist                                           0.0
# System administrator                                0.0

# %% [markdown]
# ## Log

# %%
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA + Hyperparamter tuning",
         "model_details": str(hpt_rf_clf),
         "model_object": hpt_rf_clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Preformance details
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track 
with mlflow.start_run(experiment_id=exp.experiment_id, 
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)  
    
    # Track metrics 
    for metric, score in mean_test_scores.items():
       print( mlflow.log_metric(metric, score))
# Out:
# None
# None
# None
# None

# %%
runs = mlflow.search_runs([exp.experiment_id])
runs
# Out:
#                              run_id experiment_id    status  \
# 0  79f7737b4ea44cc2b57b18ad1e6b256a             0  FINISHED
# 1  cc159051f86b415ba8c387c102682310             0  FINISHED
# 2  d7ed955116154fa9b5772997229ee015             0  FINISHED
#
#                                         artifact_uri  \
# 0  file:///C:/Users/Abdelrahman%20Ragab/Downloads...
# 1  file:///C:/Users/Abdelrahman%20Ragab/Downloads...
# 2  file:///C:/Users/Abdelrahman%20Ragab/Downloads...
#
#                         start_time                         end_time  \
# 0 2022-08-19 20:59:16.951000+00:00 2022-08-19 20:59:16.970000+00:00
# 1 2022-08-19 20:49:49.918000+00:00 2022-08-19 20:49:52.112000+00:00
# 2 2022-08-19 20:48:54.052000+00:00 2022-08-19 20:48:54.071000+00:00
#
#    metrics.recall_score  metrics.f1_score  metrics.precision_score  \
# 0             50.186875         64.286875                93.886250
# 1             50.186875         64.286875                93.886250
# 2             29.890000         38.613125                62.420625
#
#    metrics.accuracy_score tags.mlflow.source.type   tags.mlflow.user  \
# 0               92.647500                   LOCAL  Abdelrahman Ragab
# 1               92.647500                   LOCAL  Abdelrahman Ragab
# 2               88.939375                   LOCAL  Abdelrahman Ragab
#
#                               tags.mlflow.runName  \
# 0  Random Forest: with PCA + Hyperparamter tuning
# 1                 Random Forest: with PCA - Basic
# 2            Baseline model: Logistic Regression
#
#                              tags.mlflow.source.name
# 0  C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\l...
# 1  C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\l...
# 2  C:\Users\Abdelrahman Ragab\anaconda3\envs\ML\l...
